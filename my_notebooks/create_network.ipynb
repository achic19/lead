# %%
import os
from python_steps.network import *
from python_steps.get_features import *

import matplotlib.pylab as pylab
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (25, 20),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
pylab.rcParams.update(params)

# %% [markdown]
# ### I am going to work on central London as an example

# %%
import sys
os.chdir(sys.path[3])
folder_to_save_files = r'my_notebooks/progress_files.gpkg'
boroughs_polygon= gpd.read_file(os.getcwd() + '/inputs/london_districts_4326.shp')

# %%
area =boroughs_polygon[boroughs_polygon['DISTRICT']=='City and County of the City of London']
area_geometry = area['geometry'].iloc[0]

# %% [markdown]
# ### Step 1 - Download Network and calculate centrality measures:  betweenness and closeness

# %%
net_obj = Network(area_geometry, folder_to_save_files)
# Out:
# download data - 2022-07-22 15:48:39.703521
# calculate closeness at 2022-07-22 15:48:44.515967
# calculate betweenness- 2022-07-22 15:49:04.718972

# %%
import matplotlib.pyplot as plt
net_obj.edges_shp.plot(column='closeness', legend=True)
# Out:
# <AxesSubplot:>

# %%
net_obj.edges_shp.plot(column='betweenness', legend=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Each step can run separately as long as the _ntwrk layer exist in our data frame

# %%
gdb= gpd.read_file(folder_to_save_files, driver='GPKG', layer='_ntwrk')
feats = GetFeatures(gdb, area_geometry,folder_to_save_files)
# Out:
#   calculate buffer
#   download data
# C:\Users\Achituv\anaconda3\envs\ox\lib\site-packages\osmnx\geometries.py:805: ShapelyDeprecationWarning: __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#   for merged_outer_linestring in list(merged_outer_linestrings):
# C:\Users\Achituv\anaconda3\envs\ox\lib\site-packages\osmnx\geometries.py:805: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   for merged_outer_linestring in list(merged_outer_linestrings):
#  Point
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [9], in <cell line: 2>()
# ...
